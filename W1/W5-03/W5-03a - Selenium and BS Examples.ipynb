# %% [markdown]
# # 4. Selenium and BeautifulSoup Examples

# %%
import time

from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.ebay.com.my")
# htmlSource = driver.page_source
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\User\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
# Page 1
driver.find_element_by_id("gh-ac").send_keys("Xiaomi")

time.sleep(1)

driver.find_element_by_id("gh-btn").click()

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')

time.sleep(1)

# soup_list = soup.findAll("h3", attrs={"class":"s-item__title"})

# soup_list = soup.findAll("h3", attrs={"class":"s-item__title"})[0]

# print(soup_list)

soup_list = soup.findAll("a", attrs={"class":"s-item__link"})
print(soup_list)
# Out:
# [<a _sp="p2351460.m1686.l7400" class="s-item__link" data-track="" href="https://www.ebay.com/itm/01920391?epid=26039819083&amp;_trkparms=ispr%3D1&amp;hash=item3b542eae7a:g:FQkAAOSwK21gKvEZ&amp;amdata=enc%3AAQAFAAACcBaobrjLl8XobRIiIML1V4Imu%252Fn%252BzU5L90Z278x5ickkrDx%252B2NLp21dg6hHbHAkGMYdiW1E6zjXxnQ0bf7c%252Fx%252Fvs5PW%252FYFw1ZdbGMi8wsGV6qXw8OFLl4Os1ACX3bnQxFkVpRib9hMb5gVyLha4q9L0xiporu5InbX0LrSgg7nCCCwtC7y3vOE3hc8PszsrXWLb5KFdj7%252BD98et12MdkEfMPFhJZuS%252BkFsp2esVTRCYctOhcwzPSdfzCOYprlr2miQc4czCv1Tcfs3LKUPJn8uQyRc%252BAnKY1oyTeYnJ7wYuGkBU%252FSVYjziLBaPhT%252FlVu0hR9ZX6OnAeRaJ1g0iCaDjrRXEXRwUO87riWeI8kExm1zzY7QicPeMnfWZdBvVhg05GOScPOlLTVPHakqGLX0y2GUXV6fkTLua3nSF5YBmLX%252FqdCxT6yS0dutVs5MPWvQYlN474hUzbubkZVAs7Y%252BBBEsHrGjVzCj0szZ6w1%252BHgkV5O9jrXGnyew5%252Bnxy7VCq5xEkUDIt1nSg996AeDksNmSNumhfsIOGltIXbqAbjqEUpPcVO%252BDPymxlh0iMxCZQalYnmljBRzKILYWkES0vfA14Gh5E7KWrztdC6WzEEFtgVuABakQ1eAOZnuEueqK6IakC%252BIfRbXv96Tv01IPDvwPeM8wMo6j8bMjY3D5KHS5EXPVdHKUnjCJiYCcVUqcKwhL6eN2MZ%252Bn9yxmWESUPN394NPrX%252FI2z7t0Bbo7iqmsWNQcyi0EHzDwJPMK%252FNSif8%252F2adRF7dT1JrbL9sryKSN2kv9OsdGQ0fMMC1LV3Ph43HivUJdqkgjGxqEqX5v1xQ%253D%253D%7Campid%3APL_CLK%7Cclp%3A2334524" tabindex="-1"><h3 class="s-item__title s-item__title--has-tags"></h3></a>, <a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"parentrq":"a717840417d0ab8d3b617521fff9152e","pageci":"1a1cace4-5a21-11ec-b6f6-16f1294a4210","moduledtl":"mi:1686|iid:1|li:7400|luid:1|scen:Listings"}}' href="https://www.ebay.com.my/itm/273242355434?hash=item3f9e8376ea:g:MpMAAOSwSlBY0MUn" target="_blank"><h3 class="s-item__title">Xiaomi Black Shark Premium Tempered Glass Screen Protector</h3></a>, <a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"parentrq":"a717840417d0ab8d3b617521fff9152e","pageci":"1a1cace4-5a21-11ec-b6f6-16f1294a4210","moduledtl":"mi:1686|iid:2|li:7400|luid:1|scen:Listings"}}' href="https://www.ebay.com.my/itm/193942660136?hash=item2d27e22428:i:193942660136" target="_blank"><h3 class="s-item__title">Case Cover for XIAOMI BLACK SHARK 2 HELO (2018) Belt in Nylon with Two Belt L...</h3></a>, <a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"parentrq":"a717840417d0ab8d3b617521fff9152e","pageci":"1a1cace4-5a21-11ec-b6f6-16f1294a4210","moduledtl":"mi:1686|iid:3|li:7400|luid:1|scen:Listings"}}' href="https://www.ebay.com.my/itm/193770006222?hash=item2d1d97a6ce:g:J68AAOSwSpNf3q-~" target="_blank"><h3 class="s-item__title">Accessories For Xiaomi Mi 4c: Case Sleeve Belt Clip Holster Armband Mount Hol...</h3></a>, <a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"parentrq":"a717840417d0ab8d3b617521fff9152e","pageci":"1a1cace4-5a21-11ec-b6f6-16f1294a4210","moduledtl":"mi:1686|iid:4|li:7400|luid:1|scen:Listings"}}' href="https://www.ebay.com.my/itm/184556383104?hash=item2af86aeb80:g:Z2UAAOSw2p1f8UPS" target="_blank"><h3 class="s-item__title">Accessories For Xiaomi Mi 6: Case Sleeve Belt Clip Holster Armband Mount Hold...</h3></a>, <a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"parentrq":"a717840417d0ab8d3b617521fff9152e","pageci":"1a1cace4-5a21-11ec-b6f6-16f1294a4210","moduledtl":"mi:1686|iid:5|li:7400|luid:1|scen:Listings"}}' href="https://www.ebay.com.my/itm/ ...

# %%
soup_list[1]['href']
# Out:
# 'https://www.ebay.com.my/itm/273242355434?hash=item3f9e8376ea:g:MpMAAOSwSlBY0MUn'

# %%
# Linked url
soup = BeautifulSoup(driver.page_source,'html.parser')

soup_list = soup.findAll("a", attrs={"class":"s-item__link"})[1]['href']

print(soup_list)
# Out:
# https://www.ebay.com.my/itm/273242355434?hash=item3f9e8376ea:g:MpMAAOSwSlBY0MUn

# %%
# Page 2
soup = BeautifulSoup(driver.page_source,'html.parser')

soup_list = soup.findAll("a", attrs={"class":"s-item__link"})[1]['href']

driver.get(soup_list)

time.sleep(1)

print(soup_list)
# Out:
# https://www.ebay.com.my/itm/273242355434?hash=item3f9e8376ea:g:MpMAAOSwSlBY0MUn

# %%
# Page 3
soup = BeautifulSoup(driver.page_source,'html.parser')

soup_button = soup.find("a",attrs={"id":"binBtn_btn"})['href']

driver.get(soup_button)

time.sleep(1)

print(soup_button)

driver.close()
# Out:
# https://www.ebay.com.my/atc/binctr?item=273242355434&rev=0&fromPage=2047675&fb=1&gch=1

# %% [markdown]
# ### find_element_by_xpath

# %%
# from selenium import webdriver

# driver = webdriver.Firefox() # to try with firefox webdriver

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get('https://en.wikipedia.org/wiki/International_Space_Station')

time.sleep(1)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\User\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
# xPath option 1
iss_table = driver.find_element_by_xpath(r'/html/body/div[3]/div[3]/div[5]/div[1]/div[92]/table')

# xPath option 2
# iss_table = driver.find_element_by_xpath(r'//*[@id="mw-content-text"]/div/table[1]')

# xPath option 3
# iss_table = driver.find_element_by_xpath('//table')

iss_table_html = iss_table.get_attribute('outerHTML')

# Print partially
print(iss_table_html[:200])
print('\n. . .\n')
print(iss_table_html[-200:])

# print(iss_table_html)

# driver.close()
# Out:
# <table class="wikitable" style="margin:1em auto 1em auto; text-align:left; font-size:85%;">
# <tbody><tr>
# <th>Launch date (<abbr title="not earlier than">NET</abbr>)
# </th>
# <th>Spacecraft
# </th>
# <th>Missi
#
# . . .
#
# wiki/Northrop_Grumman" title="Northrop Grumman">Northrop Grumman</a>
# </td>
# <td nowrap=""><a href="/wiki/Unity_(ISS_module)" title="Unity (ISS module)"><i>Unity</i></a> nadir
# </td></tr></tbody></table>

# %%
# for ipython notebook display
# import IPython

from IPython.core.display import display, HTML

display(HTML(iss_table_html))
# Out:
# <table class="wikitable" style="margin:1em auto 1em auto; text-align:left; font-size:85%;">
# <tbody><tr>
# <th>Launch date (<abbr title="not earlier than">NET</abbr>)
# </th>
# <th>Spacecraft
# </th>
# <th>Mission
# </th>
# <th>Launch vehicle
# </th>
# <th>Launch site
# </th>
# <th>Launch provider
# </th>
# <th>Docking/berthing port
# </th></tr>
# <tr>
# <td nowrap="">21 December 2021<sup id="cite_ref-nsf-schedule_266-4" class="reference"><a href="#cite_note-nsf-schedule-266">[260]</a></sup><sup id="cite_ref-glenn-schedule_271-0" class="reference"><a href="#cite_note-glenn-schedule-271">[264]</a></sup>
# </td>
# <td nowrap="" style="background:lightblue;"><a href="/wiki/SpaceX_Dragon_2" title="SpaceX Dragon 2">Cargo Dragon</a> <a href="/wiki/Cargo_Dragon_C209" title="Cargo Dragon C209">C209</a>
# </td>
# <td nowrap=""><a href="/wiki/SpaceX_CRS-24" title="SpaceX CRS-24">SpX-24</a>
# </td>
# <td nowrap=""><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">Falcon 9 Block 5</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span> <a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a> <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span> <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td nowrap=""><a href="/wiki/Harmony_(ISS_module)" title="Harmony (ISS module)"><i>Harmony</i></a> zenith
# </td></tr>
# <tr>
# <td nowrap="">16 February 2022<sup id="cite_ref-nsf-schedule_266-5" class="reference"><a href="#cite_note-nsf-schedule-266">[260]</a></sup><sup id="cite_ref-rsw-2021_267-4" class="reference"><a href="#cite_note-rsw-2021-267">[261]</a></sup>
# </td>
# <td nowrap="" style="background:lightblue;"><a href="/wiki/Progress_(spacecraft)#Progress_MS_(2015–present)" title="Progress (spacecraft)">Progress MS</a> No. 449
# </td>
# <td nowrap=""><a href="/wiki/Progress_MS-19" title="Progress MS-19">Progress MS-19</a>
# </td>
# <td nowrap=""><a href="/wiki/Soyuz-2#Soyuz-2.1a" title="Soyuz-2">Soyuz-2.1a</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/Kazakhstan" title="Kazakhstan"><img alt="Kazakhstan" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/23px-Flag_of_Kazakhstan.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/35px-Flag_of_Kazakhstan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/46px-Flag_of_Kazakhstan.svg.png 2x" data-file-width="1000" data-file-height="500"></a></span> <a href="/wiki/Baikonur_Cosmodrome" title="Baikonur Cosmodrome">Baikonur</a> <a href="/wiki/Baikonur_Cosmodrome_Site_31" title="Baikonur Cosmodrome Site 31">Site 31/6</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/Russia" title="Russia"><img alt="Russia" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" decoding="async" width="23" height="15" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" data-file-width="900" data-file-height="600"></a></span> <a href="/wiki/Roscosmos" title="Roscosmos">Roscosmos</a>
# </td>
# <td nowrap=""><a href="/wiki/Poisk_(ISS_module)" title="Poisk (ISS module)"><i>Poisk</i></a> zenith
# </td></tr>
# <tr>
# <td nowrap="">21 February 2022<sup id="cite_ref-nsf-schedule_266-6" class="reference"><a href="#cite_note-nsf-schedule-266">[260]</a></sup>
# </td>
# <td nowrap="" style="background:#cfc;"><a href="/wiki/Crew_Dragon" class="mw-redirect" title="Crew Dragon">Crew Dragon</a> <a href="/wiki/Crew_Dragon_Resilience" title="Crew Dragon Resilience">Resilience</a>
# </td>
# <td nowrap=""><a href="/wiki/SpaceX_Axiom_Space-1" class="mw-redirect" title="SpaceX Axiom Space-1">AX-1</a>
# </td>
# <td><a href="/wiki/Falcon_9_Block_5" title="Falcon 9 Block 5">Falcon 9 Block 5</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span> <a href="/wiki/Kennedy_Space_Center" title="Kennedy Space Center">Kennedy</a> <a href="/wiki/Kennedy_Space_Center_Launch_Complex_39A" title="Kennedy Space Center Launch Complex 39A">LC-39A</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/United_States" title="United States"><img alt="United States" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/23px-Flag_of_the_United_States.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/35px-Flag_of_the_United_States.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/46px-Flag_of_the_United_States.svg.png 2x" data-file-width="1235" data-file-height="650"></a></span> <a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td nowrap=""><a href="/wiki/Harmony_(ISS_module)" title="Harmony (ISS module)"><i>Harmony</i></a> forward or zenith
# </td></tr>
# <tr>
# <td nowrap="">18 March 2022
# </td>
# <td nowrap="" style="background:#cfc;"><a href="/wiki/Soyuz_MS" title="Soyuz MS">Soyuz MS</a>
# </td>
# <td nowrap=""><a href="/wiki/Soyuz_MS-21" title="Soyuz MS-21">Soyuz MS-21</a>
# </td>
# <td nowrap=""><a href="/wiki/Soyuz-2#Soyuz-2.1a" title="Soyuz-2">Soyuz-2.1a</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/Kazakhstan" title="Kazakhstan"><img alt="Kazakhstan" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/23px-Flag_of_Kazakhstan.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/35px-Flag_of_Kazakhstan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Flag_of_Kazakhstan.svg/46px-Flag_of_Kazakhstan.svg.png 2x" data-file-width="1000" data-file-height="500"></a></span> <a href="/wiki/Baikonur_Cosmodrome" title="Baikonur Cosmodrome">Baikonur</a> <a href="/wiki/Baikonur_Cosmodrome_Site_31" title="Baikonur Cosmodrome Site 31">Site 31/6</a>
# </td>
# <td nowrap=""><span class="flagicon"><a href="/wiki/Russia" title="Russia"><img alt="Russia" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" decoding="async" width
